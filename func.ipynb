# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
from src.activations import Tanh, Sigmoid, Softmax, ReLU, PReLU, Swish
from src.losses import MSE
from src.layers import Dense
from src.model import Model

# %%
#input = np.reshape([[0, 0], [0, 1], [1, 0], [1, 1]], (4, 2, 1))
#output = np.reshape([[0], [1], [1], [0]], (4, 1, 1))

input = np.linspace(-10, 10, 1000)
input = np.reshape(input, (1000, 1, 1))

output = np.sin(input)

#input = []
#for i in range(0, 10000):
#        input.append(i)

#input = np.reshape(np.array(input), (10000, 1, 1))
#output = np.dot(input, input)

# %%
network = [
    Dense(1, 3),
    Tanh(),
    Dense(3, 1),
    Tanh()
]

model = Model(network, MSE())

# %%
model.train(input, output, epochs=1000, learning_rate=0.1)
# Out:
# epoch 1/1000   error=0.041270
# epoch 2/1000   error=0.008676
# epoch 3/1000   error=0.007213
# epoch 4/1000   error=0.013167
# epoch 5/1000   error=0.011410
# epoch 6/1000   error=0.013477
# epoch 7/1000   error=0.012079
# epoch 8/1000   error=0.012359
# epoch 9/1000   error=0.011955
# epoch 10/1000   error=0.012180
# epoch 11/1000   error=0.012197
# epoch 12/1000   error=0.012343
# epoch 13/1000   error=0.012343
# epoch 14/1000   error=0.012339
# epoch 15/1000   error=0.012278
# epoch 16/1000   error=0.012226
# epoch 17/1000   error=0.012174
# epoch 18/1000   error=0.012140
# epoch 19/1000   error=0.012114
# epoch 20/1000   error=0.012096
# epoch 21/1000   error=0.012081
# epoch 22/1000   error=0.012068
# epoch 23/1000   error=0.012056
# epoch 24/1000   error=0.012045
# epoch 25/1000   error=0.012036
# epoch 26/1000   error=0.012029
# epoch 27/1000   error=0.012024
# epoch 28/1000   error=0.012021
# epoch 29/1000   error=0.012020
# epoch 30/1000   error=0.012019
# ...

# %%
model.test(input, output)
# Out:
# error=0.715389

# %%
points = []
for x in np.linspace(-10, 10, 1000):
    y = model.predict(x)
    points.append([x, y])

points = np.array(points)

plt.scatter(points[:,0], points[:,1],)
plt.show()
# Out:
# /tmp/ipykernel_191828/3414464091.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   points = np.array(points)
